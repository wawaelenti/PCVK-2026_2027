# %% [markdown]
# <a href="https://colab.research.google.com/github/wawaelenti/PCVK-2026_2027/blob/main/Pertemuan1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **Wawa Elent Irawanti**
# ### **24410702019**
# ### **TI-2B**

# %% [markdown]
# Langkah (Step) 1:
# Pada code awal, beberapa library yang akan digunakan adalah: numpy, pandas, cv2, skimage, PIL, matplotlib

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow # for image display
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

# %% [markdown]
# Langkah (Step) 2: Baca image dari URLs - Read Image From URLs

# %%
# Membuat list untuk menyimpan url dari beberapa image
urls = ["https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg",
        "https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg",
        "https://th.bing.com/th/id/R.b4af3762c690acee9aebf3845aa259d3?rik=BKbCjuDmO8kXxg&riu=http%3a%2f%2f2.bp.blogspot.com%2f-_4XsKSWULzo%2fUIZGhNiRgtI%2fAAAAAAAACZA%2fVV5fIy-d7_o%2fs1600%2fgambar%2bkucing%2blucu%2b3.jpg&ehk=ZVra8E7YUE206BC9qTqZkFR3VRm7m1u7eOZ6gqDgX0c%3d&risl=&pid=ImgRaw&r=0"]
# baca dan tampilkan image
# loop pada tiap url image, beberapa image dapat disimpan pada list
for url in urls:
  image = io.imread(url)
  image = cv.resize(image, (0,0), fx= 0.5, fy=0.5)
  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
  final_frame = cv.hconcat((image, image_2))
  cv2_imshow(final_frame)
  print('\n')
# Out:
# <PIL.Image.Image image mode=RGB size=800x276>
# <PIL.Image.Image image mode=RGB size=800x286>
# <PIL.Image.Image image mode=RGB size=1152x432>

# %% [markdown]
# Langkah (step) 3:
# Melihat ukuran file image

# %%
tinggi = image_2.shape[0]
lebar = image_2.shape[1]
print("resolusi image: tinggi x lebar = ", tinggi, " x ", lebar)
cv2_imshow(image_2)
# Out:
# resolusi image: tinggi x lebar =  432  x  576
# <PIL.Image.Image image mode=RGB size=576x432>

# %% [markdown]
# Langkah (step) 4:
# Mengakses pixel dengan memberi garis diagonal menyilang

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# membuat garis horizontal ditengah image
for y in range (lebar):
  image_3[int((tinggi)/2),y] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=1152x432>

# %% [markdown]
# ### **Pertanyaan Praktikum D2**
# 1. Jelaskan, mengapa pada modul praktikum ini eksekusi kode Python dilakukan menggunakan Google Colab?
# 2. Jelaskan mengenai kegunaan setiap library pada praktikum langkah ke delapan? Apakah semua library tersebut harus digunakan dalam praktikum sesi ini?
# 3. Apakah kegunaan kode [255,255,255]? Jelaskan!
# 4. Jelaskan keterkaitan antara pixel dan juga resolusi gambar yang tinggi ataupun rendah!
#
# ### **Jawab**
# 1. Karena memiliki banyak keunggulan, salah satunya yaitu tidak perlu meninstall aplikasi yang terintegrasi python pada PC kita sendiri dan juga dapat langsung terhubung ke github.
# 2. Ada beberapa yang digunakan diantaranya yaitu:
#     - Numpy, berfungsi untuk melakukan manipulasi terhadap data array numerik
#     - Pandas, berfungsi untuk memanipulasi data dan melakukan analisis terhadap data tersebut
#     - CV2, berfungsi untuk pengolahan citra, deteksi objek, dan tracking
#     - cv2_imshow, berfungsi untuk menampilkan gambar
#     - Skimage, berfungsi untuk melakukan image processing
#     - PIL, berfungsi untuk pemrosesan dan manipulasi gambar
#     - Matplotlib, berfungsi untuk visualisasi data dan citra
# 3. Fungsi kode tersebut adalah  untuk membuat titik tertentu menjadi warna yang sesuai dengan warna dasar RGB. Karena menggunakn nilai 255 semua maka warna yang muncul adalah warna putih
# 4. pixel adalah sebuah titik warna dalam gambar, apabila digabungkan maka akan terbentuk sebuah gambar. Sedangkan resolusi adalah seberapa banyak pixel dalam sebuah gambar, semakin besar resolusinya maka pixelnya akan semakin banyak dan juga kualitas gambar menjadi lebih jelas serta ukuran file gambar juga semakin besar.

# %% [markdown]
# ### **Tugas Praktikum**
# 1. lakukan langkah-langkah praktikum seperti diatas.
# 2. Buat garis vertikal dan garis menyilang diagonal pada image keluaran.

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

#Membuat garis vertikal ditengah image
for x in range (tinggi):
  image_3[x,int((lebar)/2)] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)

image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

#Membuat garis menyilang diagonal pada image
for x in range (tinggi):
  image_3[x,int(x*(lebar/tinggi))] = [255,255,255]
  image_3[x,lebar-1-int(x*(lebar/tinggi))] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=1152x432>
# <PIL.Image.Image image mode=RGB size=1152x432>

# %% [markdown]
# 3. Buat garis horisontal berwarna putih dibagian tengah gambar dengan panjang tertentu.

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# Posisi garis di tengah gambar
y = int(tinggi / 2)

# Panjang garis = setengah lebar gambar
panjang = int(lebar / 2)

# Menentukan posisi awal dan akhir garis
x_awal = int((lebar - panjang) / 2)
x_akhir = x_awal + panjang

# Membuat garis horizontal berwarna putih
for x in range(x_awal, x_akhir):
    image_3[y, x] = [255, 255, 255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=1152x432>

# %% [markdown]
# 4. Buat kotak menggunakan kumpulan pixel warna putih di sembarang tempat dalam gambar.

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# Membuat kotak putih
for y in range(100, 200):
    for x in range(100, 200):
        image_3[y, x] = [255, 255, 255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=1152x432>
